# %%
# !pip install langchain langchain-core langchain-community pypdf pymupdf sentence-transformers chromadb
# Out:
# Requirement already satisfied: langchain in e:\anaconda3\envs\pytorch_env\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core in e:\anaconda3\envs\pytorch_env\lib\site-packages (1.3.0)
# Requirement already satisfied: langchain-community in e:\anaconda3\envs\pytorch_env\lib\site-packages (0.4.1)
# Requirement already satisfied: pypdf in e:\anaconda3\envs\pytorch_env\lib\site-packages (6.10.2)
# Requirement already satisfied: pymupdf in e:\anaconda3\envs\pytorch_env\lib\site-packages (1.27.2.2)
# Requirement already satisfied: sentence-transformers in e:\anaconda3\envs\pytorch_env\lib\site-packages (5.4.1)
# Requirement already satisfied: chromadb in e:\anaconda3\envs\pytorch_env\lib\site-packages (1.5.8)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain) (1.1.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-core) (0.7.33)
# Requirement already satisfied: packaging>=23.2.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.10)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in e:\anaconda3\envs\pytorch_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.10.0)
# Requirement already satisfied: certifi in e:\anaconda3\envs\pytorch_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in e:\anaconda3\envs\pytorch_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in e:\anaconda3\envs\pytorch_env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-community) (1.0.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-community) (2.14.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-community) (2.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.3)
# Requirement already satisfied: greenlet>=1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: torch>=1.11.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from sentence-transformers) (1.7.1)
# Requirement already satisfied: scipy>=1.0.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: tqdm>=4.0.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: regex!=2019.12.17 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in e:\anaconda3\envs\pytorch_env\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.3.2)
# Requirement already satisfied: build>=1.0.3 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: pybase64>=1.4.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.45.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (1.41.0)
# Requirement already satisfied: pypika>=0.48.9 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: kubernetes>=28.1.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: pyproject_hooks in e:\anaconda3\envs\pytorch_env\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in e:\anaconda3\envs\pytorch_env\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from build>=1.0.3->chromadb) (2.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.28.0)
# Requirement already satisfied: six>=1.9.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in e:\anaconda3\envs\pytorch_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in e:\anaconda3\envs\pytorch_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in e:\anaconda3\envs\pytorch_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in e:\anaconda3\envs\pytorch_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: sympy in e:\anaconda3\envs\pytorch_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-proto==1.41.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.41.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.62b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: networkx in e:\anaconda3\envs\pytorch_env\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in e:\anaconda3\envs\pytorch_env\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)

# %%
from langchain_core.documents import Document

# %%
sample_doc = Document(
    page_content="Hello World!",
    metadata={"source": "https://www.google.com"}
)

# %%
sample_doc
# Out:
# Document(metadata={'source': 'https://www.google.com'}, page_content='Hello World!')

# %%
type(sample_doc)
# Out:
# langchain_core.documents.base.Document

# %%
# Text data
from langchain_community.document_loaders.text import TextLoader

loader = TextLoader("data/Python.txt", encoding="utf-8")

# %%
document = loader.load()

# %%
document
# Out:
# [Document(metadata={'source': 'data/Python.txt'}, page_content='\ufeffPython is a high-level, interpreted programming language that has become one of the most popular and widely used languages in the world. Created by Guido van Rossum and first released in 1991, Python emphasizes simplicity and readability, making it easy for beginners to learn while remaining powerful for experienced developers. Its clean and concise syntax allows programmers to write fewer lines of code compared to many other languages, enhancing productivity and maintainability. Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming, which makes it versatile for a wide range of applications.\nSome key features and benefits of Python include:\n* Ease of Learning: Simple syntax and readability make Python beginner-friendly.\n* Versatility: Suitable for web development, data analysis, artificial intelligence, machine learning, scientific computing, automation, and more.\n* Extensive Libraries and Frameworks: Libraries like NumPy, Pandas, Matplotlib, and frameworks like Django and Flask accelerate development.\n* Cross-Platform Compatibility: Python programs can run on Windows, macOS, Linux, and other platforms without major modifications.\n* Strong Community Support: A large and active community provides extensive documentation, tutorials, and open-source resources.\n* Integration Capabilities: Python can integrate with other languages like C/C++, Java, and supports REST APIs, databases, and cloud services.\n* Rapid Prototyping: Python allows for quick development and testing of ideas due to its interpreted nature and ease of use.\nPython’s combination of simplicity, flexibility, and a rich ecosystem makes it a top choice for developers, researchers, and enterprises worldwide, whether building small scripts or complex, large-scale applications.')]

# %%
# # PDF data
# from langchain_community.document_loaders.pdf import PyPDFLoader

# pdf_loader = PyPDFLoader("data/research.pdf")

# document = pdf_loader.load()
# document

# %%
# # PDF data
# from langchain_community.document_loaders.pdf import PyMuPDFLoader

# pdf_loader = PyMuPDFLoader("data/research.pdf")

# document = pdf_loader.load()
# document

# %% [markdown]
# ## Ingestion Pipeline

# %%
# Data => Documents
import os
from langchain_community.document_loaders.pdf import PyPDFLoader

# %% [markdown]
# ### Documents

# %%
def load_all_pdfs():
    folder_path = "data/pdfs"
    num_docs = 0
    all_docs = []

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(".pdf"):
            # complete file path
            pdf_path = os.path.join(folder_path, filename)

            loader = PyPDFLoader(pdf_path)
            doc = loader.load()
            
            all_docs.extend(doc)
            num_docs += 1

    print("total pdfs:", num_docs)
    print("total pages:", len(all_docs))
    return all_docs

# %%
all_pdf_documents = load_all_pdfs()
# Out:
# total pdfs: 1
# total pages: 21

# %%
type(all_pdf_documents[1])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# ### Chunks

# %%
# chunks
# !pip install langchain_text_splitters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

def split_docs(documents, chunk_size=500, chunk_overlap=50):
    
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = chunk_size,
        chunk_overlap = chunk_overlap
    )

    chunked_docs = text_splitter.split_documents(documents)
    return chunked_docs

# %%
chunks = split_docs(all_pdf_documents)

# %%
len(chunks)
# Out:
# 244

# %% [markdown]
# ### Embedding

# %%
from sentence_transformers import SentenceTransformer

# %%
class EmbeddingManager:
    def __init__(self, model_name="all-MiniLM-L6-v2"):
        
        self.model_name=model_name
        print("loading model....", self.model_name)
        self.model = SentenceTransformer(self.model_name)
        print("embedding dimensions=", self.model.get_sentence_embedding_dimension())


    def generate_embeddings(self, text):
        embeddings = self.model.encode(text, show_progress_bar=True)
        print("embeddings shape:", embeddings.shape)
        return embeddings

# %%
embedding_manager = EmbeddingManager()
# Out:
# loading model.... all-MiniLM-L6-v2
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# embedding dimensions= 384
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19632\4021223045.py:7: FutureWarning: The `get_sentence_embedding_dimension` method has been renamed to `get_embedding_dimension`.
#   print("embedding dimensions=", self.model.get_sentence_embedding_dimension())

# %% [markdown]
# ### Vector Store

# %%
import chromadb
import uuid

# %%
class VectorStoreManager:
    def __init__(self, persist_directory="data/vector_store", collection_name="pdf_documents"):
        self.collection_name = collection_name
        self.persist_directory = persist_directory
        self.collection = None
        self.client = None

        self._initialize_store()

    def _initialize_store(self):
        os.makedirs(self.persist_directory, exist_ok=True)
        
        # create a client
        self.client = chromadb.PersistentClient(path=self.persist_directory)

        # create the collection
        self.collection = self.client.get_or_create_collection(
            name=self.collection_name,
            metadata={"description": "vector store collection for pdf embeddings in RAG"}
        )

        print("initialized the vector store with collection:", self.collection_name)
        print("docs in collection:", self.collection.count())

    def add_documents(self, documents, embeddings):
        if len(documents) != len(embeddings):
            raise ValueError("num of documents does not match num of embeddings")


        # store => ids, embedding, document, metadata
        ids = []
        all_metadata = []
        documents_content = []
        embeddings_list = []

        for i, (doc, embedding) in enumerate(zip(documents, embeddings)):
            doc_id = f"doc_{uuid.uuid4()}"
            ids.append(doc_id)

            metadata = dict(doc.metadata)
            metadata["doc_index"] = i
            metadata["content_length"] = len(doc.page_content)
            all_metadata.append(metadata)

            documents_content.append(doc.page_content)

            embeddings_list.append(embedding.tolist())

            self.collection.add(
                ids=ids,
                metadatas=all_metadata,
                documents=documents_content,
                embeddings=embeddings_list
            )

        print("total documents added in vector store=", len(documents_content))
        print("docs in collection:", self.collection.count())

# %%
vector_store = VectorStoreManager()
# Out:
# initialized the vector store with collection: pdf_documents
# docs in collection: 0

# %%
# data => documents => chunks => embeddings => store in vector store

texts = [doc.page_content for doc in chunks]

emebedding = embedding_manager.generate_embeddings(texts)

vector_store.add_documents(chunks, emebedding)
# Out:
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# embeddings shape: (244, 384)
# total documents added in vector store= 244
# docs in collection: 244

# %% [markdown]
# # Retrieval Pipeline

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
class RAGRetriever:
    def __init__(self, embedding_manager, vector_store):
        self.embedding_manager = embedding_manager
        self.vector_store = vector_store


    def retrieve(self, query, top_k=5, score_threshold=0.0):
        # query => embedding
        query_embeddings = self.embedding_manager.generate_embeddings([query])[0]

        # semantic search
        results = self.vector_store.collection.query(
            query_embeddings=[query_embeddings.tolist()],
            n_results=top_k
        )

        # cosine similarity
        retrieved_docs=[]
        
        if results["documents"] and results["documents"][0]:
            ids = results["ids"][0]
            metadatas = results["metadatas"][0]
            documents = results["documents"][0]
            distances = results["distances"][0]

            for i, (doc_id, metadata, document, distance) in enumerate(zip(ids, metadatas, documents, distances)):
                similarity_score = 1 - distance

                if similarity_score >= score_threshold:
                    retrieved_docs.append({
                        "id": doc_id,
                        "document": document,
                        "metadata": metadata,
                        "distance": distance,
                        "similarity_score": similarity_score,
                        "rank" : i + 1
                    })

            print(f"retrieved {len(retrieved_docs)} documents")

        else:
            print("no documents found")

        return retrieved_docs

# %%
rag_retriever = RAGRetriever(embedding_manager, vector_store)

# %%
rag_retriever.retrieve("What is encoder decoder")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# embeddings shape: (1, 384)
# retrieved 0 documents
# []

# %% [markdown]
# # Integrate with LLMs

# %% [markdown]
# ## OpenAI - GPT

# %%
API_KEY_OPENAI = "paste-your-api-key-here"

# %%
# !pip install langchain-openai

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    openai_api_key=API_KEY_OPENAI,
    model="gpt-5.4",
    temperature=0.1,
    max_tokens=1024
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from langchain_openai import ChatOpenAI
#       3 llm = ChatOpenAI(
#       4     openai_api_key=API_KEY_OPENAI,
#       5     model="gpt-5.4",
#       6     temperature=0.1,
#       7     max_tokens=1024
#       8 )
#
# ModuleNotFoundError: No module named 'langchain_openai'

# %%
# generate our retrieval-augmented output
def generate_output(query, retriever, llm, top_k=3):
    results = retriever.retrieve(query, top_k)

    context = "\n".join([doc["document"] for doc in results]) if results else ""

    if not context:
        print("we found no relevant context for the given query")

    # context + query
    prompt = f""" use given context to generate the answer for the query
                Context: {context}
                Query: {query} """

    response = llm.invoke(prompt) # expecting a string as prompt
    return response.content

# %%
answer = generate_output("what is encoder-decoder?", rag_retriever, llm)

# %%
print(answer)

# %% [markdown]
# ### Groq

# %%
API_Key_GROQ = "paste-your-api-key-here"

# %%
# !pip install langchain-groq

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    groq_api_key=API_Key_GROQ,
    model="qwen/qwen3-32b",
    temperature=0.1,
    max_tokens=1024
)

# %%
# generate our retrieval-augmented output
def generate_output(query, retriever, llm, top_k=3):
    results = retriever.retrieve(query, top_k)

    context = "\n".join([doc["document"] for doc in results]) if results else ""

    if not context:
        print("we found no relevant context for the given query")

    # context + query
    prompt = f""" use given context to generate the answer for the query
                Context: {context}
                Query: {query} """

    response = llm.invoke([prompt.format(context=context, query=query)]) # expecting a list as prompt
    return response.content

# %%
answer = generate_output("what is RAG?", rag_retriever, llm)

# %%
print(answer)

# %%
# Claude
# !pip install langchain-anthropic
